# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from scipy.sparse import csr_matrix, hstack
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
game_df = pd.read_csv(r'games.csv')

# %%
game_df
# Out:
#         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...

# %%
metadata = pd.read_json(r'games_metadata.json', lines=True)

# %%
metadata
# Out:
#         app_id                                        description  \
# 0        13500  Enter the dark underworld of Prince of Persia ...
# 1        22364
# 2       113020  Monaco: What's Yours Is Mine is a single playe...
# 3       226560  Escape Dead Island is a Survival-Mystery adven...
# 4       249050  Dungeon of the Endless is a Rogue-Like Dungeon...
# ...        ...                                                ...
# 50867  2296380
# 50868  1272080
# 50869  1402110
# 50870  2272250  Embark on a journey into the darkest nightmare...
# 50871  2488510
#
#                                                     tags
# 0      [Action, Adventure, Parkour, Third Person, Gre...
# 1                                               [Action]
# 2      [Co-op, Stealth, Indie, Heist, Local Co-Op, St...
# 3      [Zombies, Adventure, Survival, Action, Third P...
# 4      [Roguelike, Strategy, Tower Defense, Pixel Gra...
# ...                                                  ...
# ...

# %%
df = pd.merge(game_df, metadata, on='app_id')

# %%
df
# Out:
#         app_id                                      title date_release   win  \
# 0        13500          Prince of Persia: Warrior Within™   2008-11-21  True
# 1        22364                    BRINK: Agents of Change   2011-08-03  True
# 2       113020               Monaco: What's Yours Is Mine   2013-04-24  True
# 3       226560                         Escape Dead Island   2014-11-18  True
# 4       249050                    Dungeon of the ENDLESS™   2014-10-27  True
# ...        ...                                        ...          ...   ...
# 50867  2296380  I Expect You To Die 3: Cog in the Machine   2023-09-28  True
# 50868  1272080                                   PAYDAY 3   2023-09-21  True
# 50869  1402110                                 Eternights   2023-09-11  True
# 50870  2272250                        Forgive Me Father 2   2023-10-19  True
# 50871  2488510                                  FatalZone   2023-10-23  True
#
# ...

# %% [markdown]
# ## Normalizing Data

# %%
numColumns = ['positive_ratio', 'user_reviews', 'price_final', 'price_original', 'discount']

# %%
scaler = MinMaxScaler()
num_scaled = scaler.fit_transform(df[numColumns])
num_sparse = csr_matrix(num_scaled)

# %%
# num_sparse = num_sparse.get_dummies(num_sparse, columns=['tags'])
# Out:
# <50872x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 186671 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Text Description

# %% [markdown]
# **Features:** Words
# **Stop Words:** Unimportant Words
# **ngram:** Number of words in a feature (phrase)

# %%
Tfidf = TfidfVectorizer(max_features=10000, stop_words='english', ngram_range=(1, 2))

# %%
desc_matrix = Tfidf.fit_transform(df['description'])

# %%
desc_matrix
# Out:
# <50872x10000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 745610 stored elements in Compressed Sparse Row format>
