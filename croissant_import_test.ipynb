# %%
import mlcroissant as mlc
import pandas as pd

# %%
ds = mlc.Dataset("https://www.kaggle.com/datasets/antonkozyriev/game-recommendations-on-steam/croissant/download")
# Out:
# WARNING:absl:WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'rai', 'examples'}
# WARNING:absl:Found the following 1 warning(s) during the validation:
#   -  [Metadata(Game Recommendations on Steam)] Property "https://schema.org/version" is recommended, but does not exist.

# %%
for rs in ds.metadata.record_sets:
    print(rs.id, "→", rs.name)
# Out:
# games.csv → games.csv
# recommendations.csv → recommendations.csv
# users.csv → users.csv

# %%
csv_id = "games.csv"
df = pd.DataFrame(ds.records(record_set=csv_id))

# %%
df
# Out:
#       games.csv/app_id                                  games.csv/title  \
# 0             b'13500'  b'Prince of Persia: Warrior Within\xe2\x84\xa2'
# 1             b'22364'                       b'BRINK: Agents of Change'
# 2            b'113020'                  b"Monaco: What's Yours Is Mine"
# 3            b'226560'                            b'Escape Dead Island'
# 4            b'249050'            b'Dungeon of the ENDLESS\xe2\x84\xa2'
# ...                ...                                              ...
# 50867       b'2296380'     b'I Expect You To Die 3: Cog in the Machine'
# 50868       b'1272080'                                      b'PAYDAY 3'
# 50869       b'1402110'                                    b'Eternights'
# 50870       b'2272250'                           b'Forgive Me Father 2'
# 50871       b'2488510'                                     b'FatalZone'
#
#       games.csv/date_release  games.csv/win  games.csv/mac  games.csv/linux  \
# ...
